# %% [markdown]
# <a href="https://colab.research.google.com/github/Awesome-Areej/Awesome-Areej/blob/main/Peono.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Integers
#
# **0. Outline**
#
#
# 1.   Peano axiomatization of integers
# 2.   Recursivity: examples successor, factorial and fubonacci
# 3.   Prime numbers
# 4.   Proof primes are infinite + function that does that
# 5.   Goldbach's conjecture

# %% [markdown]
# **1. Peano axiomatization of integers**
#
# According to G. Peano, to generate all natural integers one needs three ingredients
#
# 1.   the number zero
# 2.   the number one
# 3.   a recursive function called a successor
#
# Giuseppe Peano (1858–1932), Italian mathematician.

# %%
def successor(n):
  if n ==0:
    return 1
  else:
    return successor(n-1) +1

# %%
successor(0)
# Out:
# 1

# %%
successor(1)
# Out:
# 2

# %%
successor(2)
# Out:
# 3

# %% [markdown]
# **Theorem 1.:** Integers are infinite.
#
# **Proof:** To prove that there is no largest number, take the so called 'biggest' number, and add one, or any number for that matter, to it, creating an even larger number than before.

# %% [markdown]
# **2. Recursive Functions**
#
# A recursive function is a function that calls itself within the code. This function stops when it reaches a certain point, or a base case.
#
#
# Below are some examples of such functions

# %%
def factorial(n):
  if n == 0:
    return 1
  else:
    return n*factorial(n-1)

# %%
 factorial(200)
# Out:
# 

# %%
def fibonnaci(n):
  if n == 0:
    return 0
  elif n == 1:
    return 1
  else:
    return fibonnaci(n-1) + fibonnaci(n-2)

# %%
fibonnaci(10)
# Out:
# 55

# %% [markdown]
# ![pic.png](data:image/png;base64,...)

# %% [markdown]
# Notice that the reccursive  fibonnaci is not efficient as for say, n=10, the function fibonnaci(n) calls itself 2**10 times!!!!!

# %% [markdown]
# **3. Prime numbers.**
#
#
# **Definition:** A *prime number* is an integer, bigger than one, that can only be divided by one and itself. Examples: 2, 3, 5 and 7.
#
#
# Here is a function that tests whether an integer is a prime number or not.

# %%
def is_prime(n, verbose=False):
  for i in range(2, n):
    if n % i == 0:
      if verbose:
        print (f'divisor {i} found for {n}')
      return False
  return True

# %%
is_prime(9, verbose=True)
# Out:
# divisor 3 found for 9
# False

# %% [markdown]
# **Theorem 2**. The set of prime numbers is infinite.
#
# **Proof:** Multiply all known prime integers and add one. This causes you to always have a non-zero remainder.

# %% [markdown]
# **4. Goldbach conjecture.**  *Who wants to win a million dollar!!*
#
# Prove that every even number, bigger than 2, is a sum of two primes.
#
# Examples: 8 = 3+5, 20 = 13 + 7.
